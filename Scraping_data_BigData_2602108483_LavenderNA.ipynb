# %% [markdown]
# <a href="https://colab.research.google.com/github/lavendernathania/BigData-ScrapingData/blob/main/Scraping_data_BigData_2602108483_LavenderNA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#2602108483
#Lavender Nathania Adelya

# %%
pip install google-play-scraper #untuk menginstal pustaka Python bernama google-play-scraper

# %%
from google_play_scraper import app #untuk mengimpor pustaka dan fungsi yg akan digunakan utk mengambil data dari google play store
import pandas as pd
import numpy as np

# %%
#Scrape data dengan jumlah tertentu

from google_play_scraper import Sort, reviews

result,continuation_token = reviews( #ntuk mengambil data review dari Google Play Store
    'com.linecorp.LGGRTHN', #menggunakan data dari game Line Get Rich
    lang='id', #bahasa indonesia
    country='id', #negara indonesia
    sort=Sort.MOST_RELEVANT,
    count=1000, #mengambil data 1000
    filter_score_with=None
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review']) #untuk mengambil data dari kolom review, menghapusnya dari DataFrame, dan mengubahnya menjadi list Python biasa

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist())) #untuk memecah data yang awalnya disimpan dalam satu kolom (review) yang berisi nested list menjadi beberapa kolom baru.

df_busu.head() #Menampilkan lima baris pertama dari DataFrame df_busu setelah transformasi.
# Out:
#                                reviewId      userName  \
# 0  3b5eb084-6e11-4fb2-8f2d-bcd3ebce62ed      Star ExE
# 1  7bf5155b-262f-4366-bc95-dc7b5278f37b          Obiy
# 2  6db322ad-4f0e-4578-820a-60fdc9627266  AJI EGY TAMA
# 3  3bb0cd11-4c76-4820-bcf2-74b6a0ea153b     Aji Citro
# 4  a4ac1017-8437-4c1a-ad62-8b3291b4be66      yusamr _
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Makin ke sini makin banyak bug padahal bukan g...      1             24
# 1  Semenjak Update banyak Bug seperti login dan m...      1              2
# 2  2024 mencoba memainkan kembali... terakhir 201...      1             37
# ...

# %%
len(df_busu.index) #jumlah data yang kita dapat
# Out:
# 1000

# %%
df_busu[['userName', 'score','at', 'content']].head() #preview username, rating, date-time, dan reviews
# Out:
#        userName  score                  at  \
# 0      Star ExE      1 2024-11-22 23:50:44
# 1          Obiy      1 2024-11-25 04:23:51
# 2  AJI EGY TAMA      1 2024-11-07 12:49:23
# 3     Aji Citro      1 2024-10-23 14:28:27
# 4      yusamr _      1 2024-10-09 10:04:51
#
#                                              content
# 0  Makin ke sini makin banyak bug padahal bukan g...
# 1  Semenjak Update banyak Bug seperti login dan m...
# 2  2024 mencoba memainkan kembali... terakhir 201...
# 3  Ini akan dijelaskan kenapa bintang 1. Pertama ...
# 4  Mohon untuk di perbaiki laik bug nya, suara yg...

# %%
#sorting bedasarkan tanggal

new_df = df_busu[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False) #Sorting berdasarkan yang terbaru
sorted_df.head()
# Out:
#              userName  score                  at  \
# 26        Fikhri Crew      5 2024-11-25 16:02:34
# 352     Iswan Iswandi      1 2024-11-25 14:56:54
# 347  erfan pramugians      1 2024-11-25 13:04:12
# 355     Mujarah Ikbal      1 2024-11-25 12:39:16
# 68    Azalea Ramdhani      3 2024-11-25 11:33:18
#
#                                                content
# 26   Saya sudah beli pass nya 80K dan berhasil baya...
# 352  Game gak jelas udah di download gak bisa masuk...
# 347  game nya keluar masuk keluar masuk aplikasi mu...
# 355  Game busuk game kikir. LENGKAP KEKURANGAN NYA ...
# 68   Konsep nya gmn ini tiap kali menang lgsg kluar...

# %%
my_df = sorted_df[['userName', 'score','at', 'content']]
#untuk memilih kolom tertentu dari DataFrame sorted_df yang telah diurutkan sebelumnya dan menyimpannya dalam DataFrame baru bernama my_df.

# %%
my_df.head()
# Out:
#              userName  score                  at  \
# 26        Fikhri Crew      5 2024-11-25 16:02:34
# 352     Iswan Iswandi      1 2024-11-25 14:56:54
# 347  erfan pramugians      1 2024-11-25 13:04:12
# 355     Mujarah Ikbal      1 2024-11-25 12:39:16
# 68    Azalea Ramdhani      3 2024-11-25 11:33:18
#
#                                                content
# 26   Saya sudah beli pass nya 80K dan berhasil baya...
# 352  Game gak jelas udah di download gak bisa masuk...
# 347  game nya keluar masuk keluar masuk aplikasi mu...
# 355  Game busuk game kikir. LENGKAP KEKURANGAN NYA ...
# 68   Konsep nya gmn ini tiap kali menang lgsg kluar...

# %%
my_df.to_csv("hasil_scraping_linegetrich.csv", index = False) #simpan file berbentuk csv,

# %%
from google.colab import files
files.download('hasil_scraping_linegetrich.csv') #untuk mendownlod csv
